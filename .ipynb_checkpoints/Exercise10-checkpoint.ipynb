# %%
import pandas as pd

# %%
df = pd.read_csv("Week9_Example1.csv")
df
# Out:
#                 x             y
# 0      100.000000  1.800624e+04
# 1      107.226722  1.260074e+04
# 2      114.975700  1.378751e+04
# 3      123.284674  2.523853e+04
# 4      132.194115 -1.980269e+03
# ..            ...           ...
# 95   75646.332755  4.490780e+09
# 96   81113.083079  1.742003e+10
# 97   86974.900262  1.291802e+10
# 98   93260.334688  1.258400e+10
# 99  100000.000000  1.151518e+10
#
# [100 rows x 2 columns]

# %%
df.plot.scatter(x='x', y='y')
# Out:
# <Axes: xlabel='x', ylabel='y'>

# %%
df = pd.read_csv("Week9_Example2.csv")
df
# Out:
#               x
# 0      1.003100
# 1      1.003389
# 2      1.003698
# 3      1.004662
# 4      1.006179
# ..          ...
# 995   22.301857
# 996   27.236348
# 997   44.548669
# 998   46.776818
# 999  232.362131
#
# [1000 rows x 1 columns]

# %%
df.plot()
# Out:
# <Axes: >
