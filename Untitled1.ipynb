# %%
import pandas as pd

data = pd.read_csv('Week6_example2.csv')
data
# Out:
#        Samples
# 0     5.677934
# 1     8.491145
# 2    10.017134
# 3     9.024284
# 4     7.854364
# ..         ...
# 995   8.454700
# 996   7.384953
# 997  10.015136
# 998   8.716924
# 999   8.049497
#
# [1000 rows x 1 columns]

# %%
import seaborn as sns

sns.kdeplot(data, legend=False)
# Out:
# <Axes: ylabel='Density'>
