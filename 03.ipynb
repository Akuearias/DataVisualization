# %%
import pandas as pd

# %%
d1 = pd.read_csv('Data_from_Minard_s_famous_graphic_map_of_Napoleon_s_march_on_Moscow_898_15.csv')

# %%
d2 = pd.read_csv('Data_from_Minard_s_famous_graphic_map_of_Napoleon_s_march_on_Moscow_899_95.csv')

# %%
d3 = pd.read_csv('Data_from_Minard_s_famous_graphic_map_of_Napoleon_s_march_on_Moscow_900_85.csv')

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.scatterplot(x='long', y='lat', data=d1)
for i, row in d1.iterrows():
    plt.text(row['long'] + 0.05, row['lat'] - 0.05, row['city'], fontsize=9)
    
plt.show()

# %%
sns.scatterplot()
